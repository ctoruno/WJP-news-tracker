# %%
import os
import translators as ts
import pandas as pd
import multiprocessing as mp
import nltk
from nltk.tokenize import sent_tokenize
from deep_translator import GoogleTranslator

nltk.download("punkt")
# Out:
# Using region District of Columbia server backend.
#
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ctoruno\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Defining parameters

# %%
compiler = "carlos"
batch    = 25

# %% [markdown]
# ## Defining functions

# %%
def trans2english_batch(text, sourcelang):
    """
    This functions gathers a text in a specific language and it returns its equivalent 
    in English using the Google translation engine. 

    Parameters:
        text:       String. Text to translate.
        sourcelang: String. Code of the source language you want to translate the text from.
    """
    try:
        sentences = sent_tokenize(text)
        batch  = GoogleTranslator(source = sourcelang, target = "en").translate_batch(sentences)
        result = " ".join(batch)
        return result
    except Exception as e:
        out = f"Translation through API failed. Reason: {e}"
        return out

def parallel_translation(df):
    with mp.Pool(5) as pool:
        df[["title_trans", "description_trans", "content_trans"]] = pool.starmap(
            trans2english_batch,
            zip(
                df[["title", "description", "content"]].values.tolist(),
                df["language_id"].values.tolist()
            )
        )
    return df

# %% [markdown]
# ## Reading the data

# %%
if os.getlogin() == "ctoruno":
    master_data = pd.read_parquet("../data/eu-news-batch-unique.parquet.gzip")
else:
    master_data = pd.read_parquet("eu-news-batch-unique.parquet.gzip")
master_data["compiler"].value_counts()
# Out:
# compiler
# artha     5114
# other     5107
# dalia     5064
# santi     5049
# carlos    4894
# Name: count, dtype: int64

# %% [markdown]
# ## Subsetting the data

# %%
starting_row    = 100*(batch-1)
final_row       = starting_row+100
compiler_subset = master_data.loc[master_data["compiler"] == compiler].iloc[starting_row:final_row]

# %%
compiler_subset
# Out:
#          country                      journal  \
# 15949  [finland]           https://www.hs.fi/
# 15950  [finland]           https://www.hs.fi/
# 15958  [finland]           https://www.hs.fi/
# 15964  [finland]           https://www.hs.fi/
# 15967  [finland]           https://www.hs.fi/
# ...          ...                          ...
# 16601  [finland]           https://www.is.fi/
# 16634  [finland]           https://www.is.fi/
# 16636  [finland]           https://www.is.fi/
# 16653  [finland]           https://www.is.fi/
# 16657  [finland]  https://www.kauppalehti.fi/
#
#                               asspillar language  \
# 15949                   open_government  finnish
# 15950                   open_government  finnish
# 15958                   open_government  finnish
# 15964                   open_government  finnish
# 15967                   open_government  finnish
# ...                                 ...      ...
# 16601              fundamental_freedoms  finnish
# 16634                order_and_security  finnish
# 16636                order_and_security  finnish
# 16653                     civil_justice  finnish
# 16657  constraints_of_government_powers  finnish
#
#                              article_id  \
# 15949  021b546ae5418dea020cce9ad4d13450
# 15950  876a220e8f7131c2071802b72fa044bd
# 15958  1a40f66c1f384e704cf390ab0e29440f
# 15964  f93c3d1e6185a03889741e90596045c7
# 15967  47e667e092973a46b3fd916c4f93629d
# ...                                 ...
# 16601  70a43798b9583112dce3b18b66b54680
# 16634  f331698f8d0560a715c367882f98783f
# 16636  0fa25aabc906de9b0b4f711afd92ed4d
# 16653  dc3136f0eabbf9e84202798ceff34c45
# 16657  e7909d9c47fc6fc3672605f7c6a94969
#
#                                                    title  \
# 15949  Iskut Venäjälle | Moskovaan tehtiin taas lenno...
# 15950  Twitter | Rap-artisti Kanye Westin tili palaut...
# 15950  https://hs.mediadelivery.fi/img/1440/2b9487610...           hs
# 15958  https://hs.mediadelivery.fi/img/1440/1d8334b25...           hs
# 15964  https://hs.mediadelivery.fi/img/1440/31348f4e8...           hs
# 15967  https://hs.mediadelivery.fi/img/1440/b00ae7be7...           hs
# ...                                                  ...          ...
# 16601  https://is.mediadelivery.fi/img/1440/c026aaff2...           is
# 16634  https://is.mediadelivery.fi/img/1440/b79e89aaa...           is
# 16636  https://is.mediadelivery.fi/img/1440/bd08b9878...           is
# 16653  https://is.mediadelivery.fi/img/1440/bfe994e9a...           is
# 16657                                               None  kauppalehti
#
#        source_priority       category language_id compiler
# 15949         139886.0          [top]          fi   carlos
# 15950         139886.0  [environment]          fi   carlos
# 15958         139886.0          [top]          fi   carlos
# 15964         139886.0  [environment]          fi   carlos
# 15967         139886.0  [environment]          fi   carlos
# ...                ...            ...         ...      ...
# 16601          55661.0          [top]          fi   carlos
# 16634          55661.0          [top]          fi   carlos
# 16636          55661.0          [top]          fi   carlos
# 16653          55661.0          [top]          fi   carlos
# 16657         751048.0          [top]          fi   carlos
#
# [100 rows x 19 columns]

# %% [markdown]
# ## Translating headline, description, and content

# %%
compiler_subset[["title_trans", "description_trans", "content_trans"]] = compiler_subset.apply(
    lambda row: row[["title", "description", "content"]].apply(lambda x: trans2english_batch(text = x, sourcelang = row["language_id"])),
    axis = 1
)

# %%
setcols = ["country", "journal", "language", "title", "description", "content", "title_trans", "description_trans", "content_trans"]
print("==== Title ====")
print(compiler_subset.loc[compiler_subset.title_trans.str.contains("Translation through API failed") == True, setcols].value_counts("title_trans"))
print("==== Description ====")
print(compiler_subset.loc[compiler_subset.description_trans.str.contains("Translation through API failed") == True, setcols].value_counts("description_trans"))
print("==== Content ====")
print(compiler_subset.loc[compiler_subset.content_trans.str.contains("Translation through API failed") == True, setcols].value_counts("content_trans"))
# Out:
# ==== Title ====
# title_trans
# Translation through API failed. Reason: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=fi&q=Alkoholia+voi+ensi+vuonna+tilata+kotiinkuljetuksella+kaupasta%2C+ravintolasta+ja+Alkosta%2C+jos+hallituksen+tavoite+toteutuu (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))                                                              1
# Translation through API failed. Reason: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=fi&q=Bild%3A+Rammsteinin+toimistoon+hy%C3%B6k%C3%A4ttiin (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))                                                                                                                                       1
# Translation through API failed. Reason: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=fi&q=HS+Turku+%7C+N%C3%A4in+neuvosto%C2%ADdiplomaatit+saivat+1970-luvulla+Turussa+poikkeuksellisen+edun+%E2%80%93+Nyt+kaupunki+irti%C2%ADsanoo+vanhan+sopimuksen (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))                               1
# Translation through API failed. Reason: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=fi&q=IL%3A+Jasmin+Voutilaisen+yst%C3%A4v%C3%A4+paljastaa+%E2%80%93+t%C3%A4llaisia+olivat+27-vuotiaana+kuolleen+n%C3%A4yttelij%C3%A4n+viimeiset+ajat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))                                            1
# Translation through API failed. Reason: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=fi&q=Influenssarintamalla+on+viel%C3%A4+rauhallista+%E2%80%93+turkistarhoilla+ty%C3%B6skentelevi%C3%A4+suositellaan+ottamaan+influenssarokotus (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))                                                 1
# Translation through API failed. Reason: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=fi&q=Iskut+Ven%C3%A4j%C3%A4lle+%7C+Moskovaan+tehtiin+taas+lennokki-isku%2C+vauriot+pormestarin+mukaan+lievi%C3%A4 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))                                                                              1
# Translation through API failed. Reason: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=fi&q=Israelin+maahy%C3%B6kk%C3%A4yksest%C3%A4+Gazaan+ennakoidaan+hidasta+ja+verist%C3%A4 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))                                                                                                       1
# Translation through API failed. Reason: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=fi&q=
# 16118                                               None
# 16135  Suomessa energiantuotannon perusta on jo kunno...
# 16139  Konservatiivisen Høyre-puolueen kansanedustaja...
# 16140  Maahanmuuttoviraston mukaan korkeimman hallint...
# 16149                                               None
# 16162                                               None
# 16166                                               None
# 16168                                               None
# 16172                                               None
# 16187                                               None
# 16191                                               None
# 16195                                               None
# 16204                                               None
# 16209                                               None
# 16212                                               None
# 16215                                               None
# 16220                                               None
# 16233                                               None
# 16240                                               None
# 16243                                               None
# 16281                                               None
# 16282                                               None
# 16299                                               None
# 16344                                               None
# 16401  Elokuvafestivaalilla vieraillut näyttelijä jou...
# 16409  Historiallista draamaa ja ihmissuhteita sekoit...
# 16420  Fleksaajat-sarjan juontaja Seksikäs-Suklaa eli...
# 16424  Salatuista elämistä tuttu näyttelijä kuoli maa...
# 16434  Vierasvenesatamasta löytyneen hukkuneen henkil...
# 16437  Kaivinkoneen kauha kolahti yllättävään esinees...
# 16455  Entinen pääministeri alkaa neuvoa muita poliit...
# 16463  Lapsen katuminen on yksi yhteiskunnan kiellety...
# 16468  Jevgeni Prigozhinilla ja Vladimir Putinilla ol...
# 16472  Vain Ukraina voi päättää, millainen rauhanratk...
# 16491  Ilta-Sanomat listaa Japanin GP:n onnistujat ja...
# 16530  Suomalaiset kausikortinhaltijat kertovat, mitä...
# 16556  Veikkausliigassa VPS on kovassa nousuvireessä....
# 16561  Vandaalit iskivät saksalaisyhtiön toimitiloihi...
# 16573  Syytteiden mukaan aiemmilla tuomioilla ei ole ...
# 16578  Poliisi sai tiedon sivullisen jalankulkijan ku...
# 16583  "Kurdikettu" voi menettää Turkin kansalaisuute...
# 16592  Omalla esimerkillä on väliä. Nuorta kannattaa ...
# 16601  Bellingcatin Christo Grozev arvioi elokuun puo...
# 16634  Video kahteen naiseen kohdistuvasta seksuaalis...
#
#                                                  content  \
# 15950  Sosiaalisen median alusta Twitter, nykyisin my...
# 15958  Venäjän pääkonsulaatin henkilökunnan vuosikymm...
# 16001  Istanbulilainen yliopisto-opettaja Sevgi lukeu...
# 16004  Ruuhkat Helsinki-Vantaan lentoasemalla jatkuva...
# 16019  A ntti Lindtman valittiin perjantai-iltana Sdp...
# 16059  Tukholma Ruotsi on joutunut huonojen uutisten ...
# 16067  Yhdysvaltalainen viihde- ja jazzlaulaja Tony B...
# 16072  Hannah näyttää saamaansa kirjaa valvontakamera...
# 16077  Salibandyseura Esport Oilersin toiminnanjohtaj...
# 16090  Muurari Ural Agejev napauttaa tiiltä, ja se ka...
# 16108                                               None
# 16111                                               None
# 16116                                               None
# 16118                                               None
# 16135  T ampereen historiaa tuntevat tietävät, mikä r...
# 16139                                               None
# 16140                                               None
# 16149  Sanna Nikula / STT Alkoholia voi ensi vuonna t...
# 16162  Johanna Latvala / STT Monet hakeutuvat pariter...
# 16166  Sini Ihanainen-Alanko Venäjä pyrkii kohottamaa...
# 16168  Terhi Riolo Uusivaara / STT Varainsiirtoveron ...
# 16172  Niilo Simojoki / STT Muun muassa norjalaisseis...
# 16187  Anne Salomäki, Nina Törnudd / STT Presidentti ...
# 16191  Eetu Kokkinen, STT Israelissa järjestetyn musi...
# 16195  Jaakko Vilmusenaho Venäjä harkitsee vetäytymis...
# 16204  Johanna Latvala / STT Influenssaepidemian käyn...
# 16209  Mikko Gustafsson / STT EU-maiden valtiovarainm...
# 16212  Minja Viitanen, Sanna Raita-aho, Eeva Nikkilä-...
# 16215  Mimma Lehtovaara / STT Israelin maahyökkäystä ...
# 16220  Kalle Kinnunen / STT Valoa valoa valoa kertoo ...
# 16233  Anssi Rulamo / STT Israelin toipuessa Hamasin ...
# 16240  Alina Salomaa / STT Toukokuussa sauvolaiselle ...
# 16243  Viivi Salminen / STT Monilla hyvinvointialueil...
# 16281  STT –AFP Israelin armeija on jatkanut keskivii...
# 16282  Lassi Lapintie, Merja Kallikari / STT Norjalai...
# 16299  STT Valkoisen talon mukaan Yhdysvaltain presid...
# 16344  Niilo Simojoki / STT Nobelin rauhanpalkinnon s...
# 16401                                               None
# 16409  Hollywoodin supertähdeksi noussut Margot Robbi...
# 16420  Olen mietteliäs. Olen herkkä. Minulla on ADHD....
# 16424                                               None
# 16434                                               None
# 16437                                               None
# 16455  Kansanedustaja , entinen pääministeri Sanna Ma...
# 16463  Sinä iltana Milla , 27, soitti itse lastensuoj...
# 16468  Syyskuussa 2022 oli Jevgeni Prigozhinin aika t...
# 16472  U kraina viettää torstaina itsenäisyyspäivää p...
# 16491  Red Bullin Max Verstappen voitti ylivoimaiseen...
# 16530  S uomalaisittain voisi ajatella kausikortin os...
# 16556  Veikkausliiga: Ilves tiputti torstaina Veikkau...
# 16561  Saksalaislehti Bild kertoo, että kohuissa rype...
# 16573  Tuomaria , syyttäjää, asianajajaa ja useita na...
# 16578                                               None
# 16583  Ruotsia piinaavan jengiväkivallan keskeisenä t...
# 16592  L ukeminen kannattaa aina. Näin sanoi edesmenn...
# 16601  Tutkivan journalismin ryhmä Bellingcatin toimi...
# 16634  Kahteen naiseen kohdistettu seksuaalinen väkiv...
#
#                                              title_trans  \
# 15950  Twitter | Rap artist Kanye West's account was ...
# 15958  Translation through API failed. Reason: HTTPSC...
# 16001  Turkey's giant inflation | Inflation makes eve...
# 16004  Travel | Helsinki-Vantaa's security check was ...
# 16019  Politics | The "perfect dem" clashed with Sann...
# 16059  HS Analysis | Sweden is in a security politica...
# 16067  Obituary | Tony Bennett was the last great Ame...
# 16072  Television Review | Netflix's new hit series L...
# 16077  Construction | "The situation is catastrophic"...
# 16090  Construction | Construction industry Alho is n...
# 16108  Translation through API failed. Reason: HTTPSC...
# 16111  Translation through API failed. Reason: HTTPSC...
# 16116  Nobel Peace Prize | Mohammadi, who is in priso...
# 16118  Editorial | The Biden administration has two p...
# 16135  Editorial | Electricity should be processed in...
# 16139  Crime | Norwegian politician to VG: Finland's ...
# 16140  Immigration Office | A fugitive convicted of m...
# 16149  Translation through API failed. Reason: HTTPSC...
# 16162  According to the psychotherapist, financial wo...
# 16166  Russia is raising the value of the ruble by en...
# 16168  The activation of first-time home buyers can c...
# 16172  Translation through API failed. Reason: HTTPSC...
# 16187  Translation through API failed. Reason: HTTPSC...
# 16191  At least 260 bodies found in the music festiva...
# 16195  Russia is considering canceling the ratificati...
# 16204  Translation through API failed. Reason: HTTPSC...
# 16209  The EU, ravaged by crises, has not kept to the...
# 16212  A million people have been forced to leave the...
# 16215  Translation through API failed. Reason: HTTPSC...
# 16220                 Secret first love in 1980s Finland
# 16233  Many in Israel believed that Hamas had become ...
# 16240  An emergency video call could show what has ha...
# 16243  "I don't think it can be done by legal means" ...
# 16281  Israel continued its relentless bombardment of...
# 16282  The probable explosion detected by the Norwegi...
# 16299  According to President Niinistö, the informati...
# 16344       Nobel Peace Prize to Iranian Narges Mohammad
# 16401  Kevin Spacey in a scary situation: the horror ...
# 16409  Would you recognize 22-year-old Margot Robbie ...
# 16420  Translation through API failed. Reason: HTTPSC...
# 16424  Translation through API failed. Reason: HTTPSC...
# 16434  A person was found drowned in Loviisa - an emp...
# 16437  A wartime explosive caught Jan's attention - t...
# 16455  Evaluation: This is how Sanna Marin can make m...
# 16463  Milla reported herself to child protection and...
# 16468  Such was the crooked relationship between Puti...
# 16472  Editorial: Putin's Russia must first be beaten...
# 16491  F1 verdict: Tähtikuski became a full-fledged t...
# 16530  The passion of Epe Helenius, 72, swallows thou...
# 16556  Standard: VPS in top form can continue its win...
# 16561  Translation through API failed. Reason: HTTPSC...
# 16573  The serial stalker continued his torment - tar...
# 16578  Serious Accident in Lieto: The car veered off ...
# 16583  SVT: A suspected gang leader living in Turkey ...
# 16592  Editorial: Encourage young people to read - an...
# 16601  Translation through API failed. Reason: HTTPSC...
# 16634  A mob claws and drags two women in a video tha...
#
#                                        description_trans  \
# 15950  Kanye West's account has previously been suspe...
# 15958  Translation through API failed. Reason: expect...
# 16001  Translation through API failed. Reason: expect...
# 16004  Finavia warns that the whole of September will...
# 16019  Translation through API failed. Reason: expect...
# 16059  Translation through API failed. Reason: expect...
# 16067  Singer Tony Bennett died on July 21 at his hom...
# 16072  The competent German suspense series is about ...
# 16077  Translation through API failed. Reason: HTTPSC...
# 16090  Translation through API failed. Reason: expect...
# 16108  Translation through API failed. Reason: expect...
# 16111  Translation through API failed. Reason: expect...
# 16116  Translation through API failed. Reason: expect...
# 16118  Translation through API failed. Reason: expect...
# 16135  In Finland, the basis of energy production is ...
# 16139  According to Sveinung Stensland, a member of p...
# 16140  According to the Finnish Immigration Service, ...
# 16149  Translation through API failed. Reason: expect...
# 16162  Translation through API failed. Reason: expect...
# 16166  Translation through API failed. Reason: expect...
# 16168  Translation through API failed. Reason: expect...
# 16172  Translation through API failed. Reason: expect...
# 16187  Translation through API failed. Reason: expect...
# 16191  Translation through API failed. Reason: expect...
# 16195  Translation through API failed. Reason: expect...
# 16204  Translation through API failed. Reason: expect...
# 16209  Translation through API failed. Reason: expect...
# 16212  Translation through API failed. Reason: expect...
# 16215  Translation through API failed. Reason: expect...
# 16220  Translation through API failed. Reason: expect...
# 16233  Translation through API failed. Reason: expect...
# 16240  Translation through API failed. Reason: expect...
# 16243  Translation through API failed. Reason: expect...
# 16281  Translation through API failed. Reason: expect...
# 16282  Translation through API failed. Reason: expect...
# 16299  Translation through API failed. Reason: expect...
# 16344  Translation through API failed. Reason: expect...
# 16401  The actor who visited the film festival unexpe...
# 16409  The Pan Am series, which mixes historical dram...
# 16420  The presenter of the Fleksaajat series, Seksik...
# 16424  Translation through API failed. Reason: HTTPSC...
# 16434  The drowned person found in the guest boat har...
# 16437  The excavator's bucket crashed into a surprisi...
# 16455  The former prime minister begins to advise oth...
# 16463  A child's regret is one of the most forbidden ...
# 16468  For more than 20 years, Yevgeny Prigozhin and ...
# 16472  Only Ukraine can decide what kind of peace set...
# 16491  Ilta-Sanomat lists the winners and losers of t...
# 16530  Finnish season ticket holders tell the joys (a...
# 16556  In the Veikkausliiga, VPS is on the rise. Ther...
# 16561  Vandals attacked the premises of a German comp...
# 16573  According to the charges, previous convictions...
# 16578  The police received information about the acci...
# 16583  The "Kurdish fox" may lose his Turkish citizen...
# 16592  Translation through API failed. Reason: HTTPSC...
# 16601  Translation through API failed. Reason: HTTPSC...
# 16634  A video of sexual violence against two women w...
#
#                                            content_trans
# 15950  Translation through API failed. Reason: HTTPSC...
# 15958  Translation through API failed. Reason: HTTPSC...
# 16001  Translation through API failed. Reason: HTTPSC...
# 16004  Translation through API failed. Reason: HTTPSC...
# 16019  Translation through API failed. Reason: HTTPSC...
# 16059  Translation through API failed. Reason: HTTPSC...
# 16067  Translation through API failed. Reason: HTTPSC...
# 16072  Translation through API failed. Reason: HTTPSC...
# 16077  Translation through API failed. Reason: HTTPSC...
# 16090  Translation through API failed. Reason: HTTPSC...
# 16108  Translation through API failed. Reason: expect...
# 16111  Translation through API failed. Reason: expect...
# 16116  Translation through API failed. Reason: expect...
# 16118  Translation through API failed. Reason: expect...
# 16135  Translation through API failed. Reason: ('Conn...
# 16139  Translation through API failed. Reason: expect...
# 16140  Translation through API failed. Reason: expect...
# 16149  Translation through API failed. Reason: HTTPSC...
# 16162  Translation through API failed. Reason: HTTPSC...
# 16166  Translation through API failed. Reason: HTTPSC...
# 16168  Translation through API failed. Reason: HTTPSC...
# 16172  Translation through API failed. Reason: HTTPSC...
# 16187  Translation through API failed. Reason: HTTPSC...
# 16191  Translation through API failed. Reason: HTTPSC...
# 16195  Translation through API failed. Reason: HTTPSC...
# 16204  Translation through API failed. Reason: HTTPSC...
# 16209  Translation through API failed. Reason: HTTPSC...
# 16212  Translation through API failed. Reason: HTTPSC...
# 16215  Translation through API failed. Reason: HTTPSC...
# 16220  Translation through API failed. Reason: HTTPSC...
# 16233  Translation through API failed. Reason: HTTPSC...
# 16240  Translation through API failed. Reason: HTTPSC...
# 16243  Translation through API failed. Reason: HTTPSC...
# 16281  Translation through API failed. Reason: ('Conn...
# 16282  Translation through API failed. Reason: HTTPSC...
# 16299  Translation through API failed. Reason: HTTPSC...
# 16344  Translation through API failed. Reason: HTTPSC...
# 16401  Translation through API failed. Reason: expect...
# 16409  Translation through API failed. Reason: HTTPSC...
# 16420  Translation through API failed. Reason: HTTPSC...
# 16424  Translation through API failed. Reason: expect...
# 16434  Translation through API failed. Reason: expect...
# 16437  Translation through API failed. Reason: expect...
# 16455  Translation through API failed. Reason: HTTPSC...
# 16463  Translation through API failed. Reason: HTTPSC...
# 16468  Translation through API failed. Reason: HTTPSC...
# 16472  Translation through API failed. Reason: HTTPSC...
# 16491  Translation through API failed. Reason: HTTPSC...
# 16530  Translation through API failed. Reason: ('Conn...
# 16556  Translation through API failed. Reason: HTTPSC...
# 16561  Translation through API failed. Reason: HTTPSC...
# 16573  Translation through API failed. Reason: HTTPSC...
# 16578  Translation through API failed. Reason: expect...
# 16583  Translation through API failed. Reason: HTTPSC...
# 16592  Translation through API failed. Reason: HTTPSC...
# 16601  Translation through API failed. Reason: HTTPSC...
# 16634  Translation through API failed. Reason: HTTPSC...

# %%
if os.getlogin() == "ctoruno":
    compiler_subset.to_parquet(f"../data/translation_batches/EU_trdata_{compiler}_batch_{batch}.parquet.gzip", compression = "gzip")
else:
    compiler_subset.to_parquet(f"EU_trdata_{compiler}_batch_{batch}.parquet.gzip", compression = "gzip")

# %% [markdown]
# ## Multiprocessing translation (not working)

# %%
# if __name__ == "__main__":
#     compiler_subset_par = parallel_translation(compiler_subset)

# %% [markdown]
# ## Compiling batches

# %%
batches = os.listdir("../data/translation_batches")
batch_data = [pd.read_parquet(f"../data/translation_batches/{x}") for x in batches]
compiled_data = pd.concat(batch_data)
compiled_data.head(10)
# Out:
#       country                        journal  \
# 8   [austria]  https://www.wienerzeitung.at/
# 13  [austria]  https://www.wienerzeitung.at/
# 18  [austria]  https://www.wienerzeitung.at/
# 23  [austria]  https://www.wienerzeitung.at/
# 25  [austria]  https://www.wienerzeitung.at/
# 26  [austria]  https://www.wienerzeitung.at/
# 31  [austria]  https://www.wienerzeitung.at/
# 33  [austria]  https://www.wienerzeitung.at/
# 36  [austria]  https://www.wienerzeitung.at/
# 45  [austria]  https://www.wienerzeitung.at/
#
#                            asspillar language  \
# 8   constraints_of_government_powers   german
# 13  constraints_of_government_powers   german
# 18  constraints_of_government_powers   german
# 23  constraints_of_government_powers   german
# 25  constraints_of_government_powers   german
# 26  constraints_of_government_powers   german
# 31  constraints_of_government_powers   german
# 33  constraints_of_government_powers   german
# 36  constraints_of_government_powers   german
# 45  constraints_of_government_powers   german
#
#                           article_id  \
# 8   30c1ac3bca2d3737de521e67cfcaaf11
# 13  a07106f5aedf74895b36c832e50ba1ee
# 18  0b0551c60900b9dbc09942d8dc74c1a4
# 23  dbccedd1a05373f358adf7de8aad3374
# 25  e1705dc80ca543412b88966f32c27db0
# 26  2b65437ffac3b7f7a3f258dbe0eed9ed
# 31  819280cf97424f3467eff11713cc5d33
# 33  a90c961e6b3816b4757bd03a5f165363
# 36  d086e5692cdab023b70eda07ace090cf
# 45  38827e8cc5e8634229f43f39abc3de0f
#
#                                             title  \
# 8                              Queer statt Kaiser
# 13        Das dreckige Geschäft mit der Reinigung
# 18        Chronologie einer gescheiterten Rettung
# 23     Private bauen aus, Energieversorger zögern
# 25                         Fensterln für ein Bier
# 26  "Es war unerträglich heiß und roch nach Blut"
# 31                           Time to Say Goodbye!
# 33                  Ein Rückgang auf hohem Niveau
# 36                      Dominanz auf allen Ebenen
# 45        Kontroverse um Mitgefühl für Titan-Team
#
#                                                  link keywords creator  \
# 8   https://www.wienerzeitung.at/a/queer-bad-ischl...     None    None
# 13  https://www.wienerzeitung.at/a/das-dreckige-ge...     None    None
# 18  https://www.wienerzeitung.at/nachrichten/polit...     None    None
# 23  https://www.wienerzeitung.at/nachrichten/wirts...     None    None
# 25  https://www.wienerzeitung.at/nachrichten/polit...     None    None
# 26  https://www.wienerzeitung.at/nachrichten/polit...     None    None
# 31  https://www.wienerzeitung.at/nachrichten/kultu...     None    None
# 33  https://www.wienerzeitung.at/nachrichten/polit...     None    None
# 36  https://www.wienerzeitung.at/nachrichten/polit...     None    None
# 45  https://www.wienerzeitung.at/nachrichten/chron...     None    None
#
#    video_url  ...              pubDate  \
# 8       None  ...  2023-10-08 03:00:00
# 13      None  ...  2023-10-02 12:58:39
# 18      None  ...  2023-06-29 10:00:00
# 23      None  ...  2023-06-27 16:30:00
# 25      None  ...  2023-06-27 15:30:00
# 26      None  ...  2023-06-27 14:55:33
# 31      None  ...  2023-06-27 06:00:00
# 33      None  ...  2023-06-26 15:57:00
# 36      None  ...  2023-06-24 16:00:00
# 45      None  ...  2023-06-22 15:25:15
#
#                                             image_url      source_id  \
# 8                                                None  wienerzeitung
# 13                                               None  wienerzeitung
# 18  https://www.wienerzeitung.at/_em_daten/_cache/...  wienerzeitung
# 23  https://www.wienerzeitung.at/_em_daten/_cache/...  wienerzeitung
# 25  https://www.wienerzeitung.at/_em_daten/_cache/...  wienerzeitung
# 26  https://www.wienerzeitung.at/_em_daten/_cache/...  wienerzeitung
# 31  https://www.wienerzeitung.at/_em_daten/_cache/...  wienerzeitung
# 33  https://www.wienerzeitung.at/_em_daten/_cache/...  wienerzeitung
# 36  https://www.wienerzeitung.at/_em_daten/_cache/...  wienerzeitung
# 45  https://www.wienerzeitung.at/_em_daten/_cache/...  wienerzeitung
#
#    source_priority    category  language_id compiler  \
# 8        2003474.0       [top]           de    artha
# 13       2003474.0       [top]           de    artha
# 18       2003474.0       [top]           de    artha
# 23       2003474.0       [top]           de    artha
# 25       2003474.0       [top]           de    artha
# 26       2003474.0  [politics]           de    artha
# 31       2003474.0       [top]           de    artha
# 33       2003474.0       [top]           de    artha
# 36       2003474.0       [top]           de    artha
# 45       2003474.0       [top]           de    artha
#
#                                           title_trans  \
# 8                            Queer instead of emperor
# 13                     The dirty business of cleaning
# 18                      Chronology of a failed rescue
# 23  Private companies are expanding, energy suppli...
# 25                   Sitting in the window for a beer
# 26       "It was unbearably hot and smelled of blood"
# 31                               Time to say goodbye!
# 33                          A decline at a high level
# 36                            Dominance on all levels
# 45                  Titan Team Compassion Controversy
#
#                                     description_trans  \
# 8   Emperor Franz Joseph abdicates in 2024: Bad Is...
# 13  Cleaning workers recruited via platforms such ...
# 18  The bad news comes suddenly and unexpectedly. ...
# 23  More than 1,000 megawatts of photovoltaic capa...
# 25  It's conspiratorial if you want to buy beer in...
# 26  He is the last survivor of those terrible even...
# 31  Nineteen stacks. Nineteen stacks lie on the fl...
# 33  These are the same asylum numbers that the ÖVP...
# 36  Greece is divided into 333 municipalities acro...
# 45  Do we feel more compassion for five men missin...
#
#                                         content_trans
# 8   Bad Ischl would almost have remained one villa...
# 13  Anuya* proudly takes a bunch of a dozen keys o...
# 18  The bad news comes suddenly and unexpectedly. ...
# 23  More than 1,000 megawatts of photovoltaic capa...
# 25  It's conspiratorial if you want to buy beer in...
# 26  He is the last survivor of those terrible even...
# 31  Nineteen stacks. Nineteen stacks lie on the fl...
# 33  These are the same asylum numbers that the ÖVP...
# 36  Greece is divided into 333 municipalities acro...
# 45  Do we feel more compassion for five men missin...
#
# [10 rows x 22 columns]

# %%
compiled_data.to_parquet("../data/eu-news-batch-unique-translated.parquet.gzip", compression = "gzip")
