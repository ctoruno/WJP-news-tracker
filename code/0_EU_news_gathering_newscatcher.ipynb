# %%
import pandas as pd
import os
import requests
import json
import time
from dotenv import load_dotenv

# %% [markdown]
# ## Loading API Key

# %%
# Loading API KEY from environment
load_dotenv()
newscatcher_key = os.getenv("newscatcher_key")

# %% [markdown]
# ## Checking subscription plan

# %%
# Defining URL, header, and parameters
url      = "https://v3-api.newscatcherapi.com/api/subscription"
headers  = {"x-api-token" : newscatcher_key}

# Sending the GET
response = requests.get(url, headers=headers)

# Parsening results
json_format = json.loads(response.text)
print(json_format)
# Out:
# {'active': True, 'concurrent_calls': 2, 'plan': 'v3_nlp', 'plan_calls': 30000, 'remaining_calls': 29335, 'historical_days': 60}

# %% [markdown]
# ## Defining extraction functions

# %%
cols = ["title", "published_date", "link", "domain_url", "name_source", "language", 
        "country", "description", "content", "word_count", "is_opinion", "id"]

def newsFetcher(source):

    # Defining URL, header, and parameters
    url      = "https://v3-api.newscatcherapi.com/api/search?"
    params   = {
        "q"         : "*",
        "sources"   : source,
        "page_size" : 5 
    }
    headers  = {"x-api-token" : newscatcher_key}

    # Sending the GET
    response = requests.get(url, params=params, headers=headers)
    time.sleep(2) # The API seems to fail when overwhelmed with calls

    # Parsening the response
    json_data = json.loads(response.text)

    # Status
    status   = json_data["status"]
    nhits    = json_data["total_hits"]
    status   = json_data["status"]

    # Printing summary of results
    print(f"Source: {source}, status: {status}, total hits: {nhits}")

    # Converting to pandas data frame
    df = pd.DataFrame(json_data["articles"])

    outcome = {
        "summary" : [json_data["status"], json_data["total_hits"], json_data["status"]],
        "data"    : df 
    }

    return outcome

def sourceFetcher(source):

    print(f"Source: {source}")

    # Defining URL, header, and parameters
    url      = "https://v3-api.newscatcherapi.com/api/sources?"
    params   = {
        "source_url" : source
    }
    headers  = {"x-api-token" : newscatcher_key}

    # Sending the GET
    response = requests.get(url, params=params, headers=headers)
    time.sleep(2) # The API seems to fail when overwhelmed with calls

    # Parsening the response
    json_data = json.loads(response.text)

    # Preparing the
    if not json_data["sources"]:
        outcome = "Source not found"
    else:
        outcome = json_data["sources"][0]["name_source"]

    return outcome

# %% [markdown]
# ## Checking sources with the API

# %%
sources = pd.read_excel("../inputs/EU_sources_1.xlsx")
sources["shortURL"] = sources["URL"].replace(r"^https?://|www\.|/", "", regex=True)

# %%
sources["newscatcher"] = sources["shortURL"].apply(sourceFetcher)
# Out:
# Source: diepresse.com
# Source: derstandard.at
# Source: krone.at
# Source: profil.at
# Source: heute.at
# Source: kleinezeitung.at
# Source: volksblatt.at
# Source: vn.at
# Source: wienerzeitung.at
# Source: kurier.at
# Source: neue.at
# Source: sn.at
# Source: rtbf.be
# Source: standaard.be
# Source: lalibre.be
# Source: lesoir.be
# Source: lecho.be
# Source: tijd.be
# Source: gva.be
# Source: nieuwsblad.be
# Source: hln.be
# Source: demorgen.be
# Source: knack.be
# Source: lalibre.be
# Source: sudinfo.be
# Source: lavenir.net
# Source: burgasnews.com
# Source: varna24.bg
# Source: 24chasa.bg
# 70    https://www.helsinkitimes.fi/     English                  NaN
# 119    https://www.magyarhirlap.hu/   Hungarian         conservative
# 150         https://www.eliesma.lv/     Latvian                  NaN
# 151       https://latgaleslaiks.lv/     Latvian                  NaN
# 152      https://baltic-review.com/     English               Center
# 157       https://www.tageblatt.lu/      German          center-left
# 160                https://talk.mt/     Maltese          labor party
# 161  https://www.maltatoday.com.mt/     English  liberal, pro-europe
# 162              https://www.ad.nl/       Dutch         center-right
# 163       https://www.telegraaf.nl/       Dutch                right
# 168              https://www.ed.nl/       Dutch                  NaN
# 170    https://www.gelderlander.nl/     Dutch\t                  NaN
# 181               https://visao.pt/  Portuguese          center-left
# 196         https://www.mladina.si/     Slovene                 left
# 197  http://www.lavozdegalicia.com/     Spanish   conservative right
#
#     API Availability            shortURL       newscatcher
# 8                Yes    wienerzeitung.at  Source not found
# 20               Yes              hln.be  Source not found
# 34                No   glas-slavonije.hr  Source not found
# 47                No        archiv.hn.cz  Source not found
# 49                No           mfdnes.cz  Source not found
# 50                No            pravo.cz  Source not found
# 70                No    helsinkitimes.fi  Source not found
# 119              Yes     magyarhirlap.hu  Source not found
# 150               No          eliesma.lv  Source not found
# 151               No    latgaleslaiks.lv  Source not found
# 152               No   baltic-review.com  Source not found
# 157              Yes        tageblatt.lu  Source not found
# 160              Yes             talk.mt  Source not found
# 161               No   maltatoday.com.mt  Source not found
# 162              Yes               ad.nl  Source not found
# 163              Yes        telegraaf.nl  Source not found
# 168              Yes               ed.nl  Source not found
# 170               No     gelderlander.nl  Source not found
# 181               No            visao.pt  Source not found
# 196              Yes          mladina.si  Source not found
# 197               No  lavozdegalicia.com  Source not found

# %%
sources_nodata = sources.loc[sources["newscatcher"] == "Source not found"].shortURL.to_list()

# %% [markdown]
# ## Testing News Articles Search Endpoint

# %%
target_sources = sources["shortURL"].tolist()
test_results   = [newsFetcher(x) for x in target_sources]
# Out:
# Source: diepresse.com, status: ok, total hits: 860
# Source: derstandard.at, status: ok, total hits: 1060
# Source: krone.at, status: ok, total hits: 1850
# Source: profil.at, status: ok, total hits: 39
# Source: heute.at, status: ok, total hits: 1220
# Source: kleinezeitung.at, status: ok, total hits: 1809
# Source: volksblatt.at, status: ok, total hits: 632
# Source: vn.at, status: ok, total hits: 247
# Source: wienerzeitung.at, status: ok, total hits: 1
# Source: kurier.at, status: ok, total hits: 955
# Source: neue.at, status: ok, total hits: 97
# Source: sn.at, status: ok, total hits: 1379
# Source: rtbf.be, status: ok, total hits: 1605
# Source: standaard.be, status: ok, total hits: 590
# Source: lalibre.be, status: ok, total hits: 80
# Source: lesoir.be, status: ok, total hits: 153
# Source: lecho.be, status: ok, total hits: 281
# Source: tijd.be, status: ok, total hits: 326
# Source: gva.be, status: ok, total hits: 1972
# Source: nieuwsblad.be, status: ok, total hits: 1245
# Source: hln.be, status: ok, total hits: 0
# Source: demorgen.be, status: ok, total hits: 342
# Source: knack.be, status: ok, total hits: 297
# Source: lalibre.be, status: ok, total hits: 80
# Source: sudinfo.be, status: ok, total hits: 72
# Source: lavenir.net, status: ok, total hits: 28
# Source: burgasnews.com, status: ok, total hits: 133
# Source: varna24.bg, status: ok, total hits: 993
# Source: 24chasa.bg, status: ok, total hits: 2356
# Source: trud.bg, status: ok, total hits: 144
# Source: dnevnik.bg, status: ok, total hits: 512
# Source: capital.bg, status: ok, total hits: 16
# Source: standartnews.com, status: ok, total hits: 847
# Source: bta.bg, status: ok, total hits: 3302
# Source: glas-slavonije.hr, status: ok, total hits: 0
# Source: slobodnadalmacija.hr, status: ok, total hits: 1260
# Source: novilist.hr, status: ok, total hits: 855
# Source: 24sata.hr, status: ok, total hits: 1197
# Source: jutarnji.hr, status: ok, total hits: 1202
# Source: vecernji.hr, status: ok, total hits: 1326
# Source: rtl.hr, status: ok, total hits: 14
# Source: hrt.hr, status: ok, total hits: 350
# Source: nacional.hr, status: ok, total hits: 572
# Source: politis.com.cy, status: ok, total hits: 631
# Source: philenews.com, status: ok, total hits: 1149
# Source: cyprus-mail.com, status: ok, total hits: 483
# Source: sigmalive.com, status: ok, total hits: 29
# Source: archiv.hn.cz, status: ok, total hits: 129
# Source: blesk.cz, status: ok, total hits: 720
# Source: mfdnes.cz, status: ok, total hits: 0
# Source: pravo.cz, status: ok, total hits: 0
# Source: denik.cz, status: ok, total hits: 5855
# Source: lidovky.cz, status: ok, total hits: 536
# Source: berlingske.dk, status: ok, total hits: 7
# Source: politiken.dk, status: ok, total hits: 631
# Source: jyllands-posten.dk, status: ok, total hits: 32
# Source: fyens.dk, status: ok, total hits: 519
# Source: nordjyske.dk, status: ok, total hits: 152
# Source: information.dk, status: ok, total hits: 155
# Source: dr.dk, status: ok, total hits: 628
# Source: stiften.dk, status: ok, total hits: 128
# Source: bt.dk, status: ok, total hits: 14
# Source: postimees.ee, status: ok, total hits: 3147
# Source: delfi.ee, status: ok, total hits: 1461
# Source: epl.delfi.ee, status: ok, total hits: 72
# Source: aamulehti.fi, status: ok, total hits: 475
# Source: ksml.fi, status: ok, total hits: 810
# Source: yle.fi, status: ok, total hits: 923
# Source: hs.fi, status: ok, total hits: 225
# Source: is.fi, status: ok, total hits: 1202
# Source: helsinkitimes.fi, status: ok, total hits: 4
# Source: iltalehti.fi, status: ok, total hits: 980
# Source: ts.fi, status: ok, total hits: 145
# Source: kaleva.fi, status: ok, total hits: 272
# Source: alandstidningen.ax, status: ok, total hits: 112
# Source: hbl.fi, status: ok, total hits: 277
# Source: nyan.ax, status: ok, total hits: 79
# Source: sudouest.fr, status: ok, total hits: 2540
# Source: ledauphine.com, status: ok, total hits: 1303
# Source: estrepublicain.fr, status: ok, total hits: 1032
# Source: dna.fr, status: ok, total hits: 940
# Source: lemonde.fr, status: ok, total hits: 931
# Source: leberry.fr, status: ok, total hits: 157
# Source: ouest-france.fr, status: ok, total hits: 1567
# Source: bnn-news.com, status: ok, total hits: 64
# Source: ir.lv, status: ok, total hits: 37
# Source: la.lv, status: ok, total hits: 317
# Source: db.lv, status: ok, total hits: 21
# Source: nra.lv, status: ok, total hits: 530
# Source: eliesma.lv, status: ok, total hits: 0
# Source: latgaleslaiks.lv, status: ok, total hits: 0
# Source: baltic-review.com, status: ok, total hits: 2
# Source: ve.lt, status: ok, total hits: 501
# Source: lrytas.lt, status: ok, total hits: 1131
# Source: wort.lu, status: ok, total hits: 362
# Source: lequotidien.lu, status: ok, total hits: 219
# Source: tageblatt.lu, status: ok, total hits: 5
# Source: timesofmalta.com, status: ok, total hits: 453
# Source: independent.com.mt, status: ok, total hits: 160
# Source: talk.mt, status: ok, total hits: 0
# Source: maltatoday.com.mt, status: ok, total hits: 2
# Source: ad.nl, status: ok, total hits: 0
# Source: telegraaf.nl, status: ok, total hits: 0
# Source: nrc.nl, status: ok, total hits: 395
# Source: volkskrant.nl, status: ok, total hits: 433
# Source: dvhn.nl, status: ok, total hits: 288
# Source: trouw.nl, status: ok, total hits: 315
# Source: ed.nl, status: ok, total hits: 0
# Source: limburger.nl, status: ok, total hits: 564
# Source: gelderlander.nl, status: ok, total hits: 0
# Source: wyborcza.pl, status: ok, total hits: 15
# Source: fakt.pl, status: ok, total hits: 644
# Source: rp.pl, status: ok, total hits: 1128
# Source: dziennik.pl, status: ok, total hits: 994
# Source: polityka.pl, status: ok, total hits: 154
# Source: cmjornal.pt, status: ok, total hits: 958
# Source: publico.pt, status: ok, total hits: 784
# Source: expresso.pt, status: ok, total hits: 837
# Source: dn.pt, status: ok, total hits: 82
# Source: jn.pt, status: ok, total hits: 51
# Source: visao.pt, status: ok, total hits: 0
# Source: diariocoimbra.pt, status: ok, total hits: 78
# Source: adevarul.ro, status: ok, total hits: 1048
# Source: libertatea.ro, status: ok, total hits: 723
# Source: evz.ro, status: ok, total hits: 870
# Source: romanialibera.ro, status: ok, total hits: 332
# Source: jurnalul.ro, status: ok, total hits: 188
# Source: sme.sk, status: ok, total hits: 2120
# Source: pravda.sk, status: ok, total hits: 421
# Source: dennikn.sk, status: ok, total hits: 989
# Source: hnonline.sk, status: ok, total hits: 832
# Source: dnevnik.si, status: ok, total hits: 90
# Source: delo.si, status: ok, total hits: 480
# Source: vecer.com, status: ok, total hits: 7
# Source: primorske.svet24.si, status: ok, total hits: 9
# Source: mladina.si, status: ok, total hits: 2
# Source: lavozdegalicia.com, status: ok, total hits: 0
# Source: elcorreo.com, status: ok, total hits: 1954
# Source: elpais.com, status: ok, total hits: 1958
# Source: elnortedecastilla.es, status: ok, total hits: 1495
# Source: lavanguardia.com, status: ok, total hits: 3078
# Source: diariosur.es, status: ok, total hits: 1576
# Source: elmundo.es, status: ok, total hits: 1461
# Source: abc.es, status: ok, total hits: 3262
# Source: diariovasco.com, status: ok, total hits: 2099
# Source: laprovincia.es, status: ok, total hits: 1430
# Source: aftonbladet.se, status: ok, total hits: 1466
# Source: dn.se, status: ok, total hits: 892
# Source: expressen.se, status: ok, total hits: 1093
# Source: svd.se, status: ok, total hits: 671
# Source: gp.se, status: ok, total hits: 781
# Source: sydsvenskan.se, status: ok, total hits: 328
# Source: etc.se, status: ok, total hits: 148

# %%
summary_list = [x["summary"][1] for x in test_results]
summary_df   = pd.DataFrame(
    {
        "source" : target_sources,
        "nhits"  : summary_list
    }
)

# %%
(summary_df
 .loc[summary_df["nhits"] < 25]
 .sort_values(by = "nhits", ascending = False))
# Out:
#                   source  nhits
# 148                db.lv     21
# 84       lavoixdunord.fr     17
# 31            capital.bg     16
# 171          wyborcza.pl     15
# 40                rtl.hr     14
# 61                 bt.dk     14
# 195  primorske.svet24.si      9
# 194            vecer.com      7
# 53         berlingske.dk      7
# 157         tageblatt.lu      5
# 70      helsinkitimes.fi      4
# 152    baltic-review.com      2
# 161    maltatoday.com.mt      2
# 196           mladina.si      2
# 8       wienerzeitung.at      1
# 181             visao.pt      0
# 170      gelderlander.nl      0
# 163         telegraaf.nl      0
# 168                ed.nl      0
# 151     latgaleslaiks.lv      0
# 162                ad.nl      0
# 160              talk.mt      0
# 20                hln.be      0
# 150           eliesma.lv      0
# 119      magyarhirlap.hu      0
# 50              pravo.cz      0
# 49             mfdnes.cz      0
# 34     glas-slavonije.hr      0
# 197   lavozdegalicia.com      0

# %%
data_chunks = [x["data"] for x in test_results]
master_data = pd.concat(data_chunks)
# with pd.option_context('display.max_rows', None,
# 					'display.max_columns', None,
# 					'display.width', 1000,
# 					'display.precision', 3,
# 					'display.colheader_justify', 'left'):
# 	display(master_data.loc[:,cols])

# %%
master_data[master_data["domain_url"].isin(sources_nodata)][cols]
# Out:
#                                                title       published_date  \
# 0  Firmenpleiten: Flüchten Unternehmen aus der Ve...  2024-02-13 04:05:51
# 0  About 10,000 Finnish service workers to go on ...  2024-02-07 07:00:29
# 1  Finland's Compass Group Culinary Team strikes ...  2024-02-07 21:12:30
# 2  Widespread strikes to hit Finland: Major disru...  2024-02-09 16:00:19
# 3  VR to operate half of its long-distance trains...  2024-02-13 16:03:51
# 0              Bold Bass: Introducing Sonos Sub Mini  2024-02-07 19:21:06
# 1  Baltic simplicity and mastery of geometry: Lit...  2024-02-07 18:06:07
# 0  Tageblatt-Serie / Ein Einblick: So sieht es hi...  2024-02-07 05:48:00
# 1  Kommentar / Wahlverschiebung löst institutione...  2024-02-08 05:02:00
# 2          Basketball / Contern baut Siegesserie aus  2024-02-10 08:02:00
# 3  Fondation Lëtzebuerger Blannevereenegung / Abs...  2024-02-12 06:02:00
# 4  Moskau / Russland schreibt Estlands Regierungs...  2024-02-13 15:02:00
# 0  Indians living in Malta as likely to have a te...  2024-02-07 05:00:00
# 1  Sergei Kondratenko: Changes in the DeFi market...  2024-02-14 07:43:00
# 0  Slavko Gaber / »Ni vprašanje, ali Robert Golob...  2024-02-08 23:05:38
# 1  »Morebiten popoln vojaški vdor je zastrašujoč ...  2024-02-12 17:29:33
#
#                                                 link         domain_url  \
# 0  https://www.wienerzeitung.at/a/firmenpleiten-f...   wienerzeitung.at
# 0  https://www.helsinkitimes.fi/finland/finland-n...   helsinkitimes.fi
# 1  https://www.helsinkitimes.fi/finland/finland-n...   helsinkitimes.fi
# 2  https://www.helsinkitimes.fi/finland/finland-n...   helsinkitimes.fi
# 3  https://www.helsinkitimes.fi/finland/finland-n...   helsinkitimes.fi
# 0           https://baltic-review.com/sonos-sub-mini  baltic-review.com
# 1  https://baltic-review.com/lithuanian-straw-gar...  baltic-review.com
# 0  https://www.tageblatt.lu/headlines/ein-einblic...       tageblatt.lu
# 1  https://www.tageblatt.lu/headlines/wahlverschi...       tageblatt.lu
# 2  https://www.tageblatt.lu/sport/andere_sportart...       tageblatt.lu
# 3  https://www.tageblatt.lu/nachrichten/luxemburg...       tageblatt.lu
# 4  https://www.tageblatt.lu/headlines/russland-sc...       tageblatt.lu
# 0  https://www.maltatoday.com.mt/news/data_and_su...  maltatoday.com.mt
# 1  https://www.maltatoday.com.mt/business/tech/12...  maltatoday.com.mt
# 0  https://www.mladina.si/230623/slavko-gaber-ni-...         mladina.si
# 1  https://www.mladina.si/230664/morebiten-popoln...         mladina.si
#
#          name_source language country  \
# 0     Wiener Zeitung       de      AT
# 0     Helsinki Times       en      FI
# 1     Helsinki Times       en      FI
# 2     Helsinki Times       en      FI
# 3     Helsinki Times       en      FI
# 0  The Baltic Review       en      US
# 1  The Baltic Review       en      US
# 0          Tageblatt       de      LU
# 1          Tageblatt       de      LU
# 2          Tageblatt       de      LU
# 3          Tageblatt       de      LU
# 4          Tageblatt       de      LU
# 0         MaltaToday       en      MT
# 1         MaltaToday       en      MT
# 0            Mladina       sl      SI
# 1            Mladina       sl      SI
#
#                                          description  \
# 0  Mit Kika/Leiner und später Signa war 2023 das ...
# 0  SERVICE UNION UNITED (PAM) on Tuesday announce...
# 1  In a triumphant showcase of culinary excellenc...
# 2  Finland is bracing for a wave of political str...
# 3  VR, the Finnish state-owned railway company, a...
# 0  Within the Sonos cosmos, the Sonos Sub Mini is...
# 1  'Sodai' in Lithuanian, also known as straw mob...
# 0  900: Es ist wohl das wichtigste Gerät der Fußb...
# 1  Der 'Phare des Mamelles' vor der senegalesisch...
# 2  Düdelingens Profilazarett ist mit Stephens, Lo...
# 3  Die 'Fondation Lëtzebuerger Blannevereenegung'...
# 4  Vor dem Hintergrund zunehmender Spannungen inf...
# 0  Census shows that 48% of Indians living in Mal...
# 1  DeFi, or decentralised finance, is an innovati...
# 0  Slavko Gaber je bil nekoč minister za izobraže...
# 1  Izraelska ofenziva v Rafi v sedanjih okoliščin...
#
#                                              content  word_count  is_opinion  \
# 0  Mit Kika/Leiner und später Signa war 2023 das ...         723       False
# 0  The union revealed that the strikes will cover...         325       False
# 1  In a triumphant showcase of culinary excellenc...         451       False
# 2  Finland is bracing for a wave of political str...         414       False
# 3  VR , the Finnish state-owned railway company, ...         369       False
# 0  Within the Sonos cosmos, the Sonos Sub Mini is...        1569       False
# 1  'Sodai' in Lithuanian, also known as straw mob...         289       False
# 0  Kantine, Sprachunterricht, Fitnessraum: Im vie...         633       False
# 1  Der 'Phare des Mamelles' vor der senegalesisch...         440       False
# 2  Contern bestätigte am Freitagabend seine ausge...         480       False
# 3  Die 'Fondation Lëtzebuerger Blannevereenegung'...         133       False
# 4  Vor dem Hintergrund zunehmender Spannungen inf...         416       False
# 0  Nearly half the Indians over the age of 15 who...         683       False
# 1  Fintech expert Sergei Kondratenko says the DeF...        1131       False
# 0  © Luka Dakskobler Slavko Gaber je bil nekoč mi...         373       False
# 1  Volker Turk, visoki predstavnik Združenih naro...         305       False
#
#                                  id
# 0  87005d97f8826959d059bed39814f3c2
# 0  180374bb6a3b9d6ad3c203c8ff3604a8
# 1  7f343e146d2248bffd72a12f6d9a23f7
# 2  db8f20bf2989b3a7b727143d84817d3f
# 3  866951b83f9a0a77024514d3e9da5e5c
# 0  066ed83526971b1c61226c3154d32529
# 1  3fccfa13dc16bf9cf69095eb868df007
# 0  657a41c7e9beff90411520eb5ed8ce78
# 1  361d00c01dead94196ef32c2cd1a8d67
# 2  6bbe8238df6c60c9ce221fa83a6a6325
# 3  41fd7b156b428d3c82aac4447e988b3b
# 4  056e0a206a40d636c29302096b8e6492
# 0  c624dd16c1f7d0196bf1f7b62954c684
# 1  7b455172e51b34f2217b2239eb393c4d
# 0  7ed9a2d2785a66d06e44f11baec7781f
# 1  2540d164fb9f8db4837b15ec4e314419

# %%
master_data.loc[master_data["content"].isnull() | master_data["description"].isnull()]
# Out:
#                                                title      author  \
# 2                                            Бюлетин  Capital.bg
# 1  Local woman raises over €3,000 for Meath River...
#
#         authors journalists       published_date published_date_precision  \
# 2  [Capital.bg]        None  2024-02-08 14:14:00         timezone unknown
# 1            []          []  2024-02-07 00:00:00                     date
#
#           updated_date updated_date_precision  \
# 2  2024-02-08 17:35:45       timezone unknown
# 1                 None                   None
#
#                                                 link         domain_url  ...  \
# 2  https://www.capital.bg/biznes/imoti/2024/02/08...         capital.bg  ...
# 1  https://www.meathchronicle.ie/2024/02/07/local...  meathchronicle.ie  ...
#
#   language description                                            content  \
# 2       bg        None  Пред вас е "брой" на специализирания бюлетин з...
# 1       en        None  Quiz and raffle fundraiser at The Willows Pub ...
#
#   word_count is_opinion twitter_account  \
# 2        199      False      @capitalbg
# 1        314      False            None
#
#                                            all_links  \
# 2  [https://mediakit.economedia.bg/advertising/#h...
# 1  [https://www.anglocelt.ie/, http://www.offalyi...
#
#                                     all_domain_links  \
# 2  [youtube.com, linkedin.com, digitalkconference...
# 1  [offalyindependent.ie, westmeathexaminer.ie, a...
#
#                                  id     score
# 2  ec897006e1ec20e2803eb03922e60ca1  1.699454
# 1  cc8ade33806928c68e1781016828703f  1.203476
#
# [2 rows x 29 columns]
